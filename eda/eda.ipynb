# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

# %%
# # save to png
# with rasterio.open("data/sample.tif") as src:
#     with rasterio.open('data/preview.png', 'w',
#         driver='PNG',
#         width=src.width,
#         height=src.height,
#         count=src.count,
#         dtype=src.dtypes[0]) as dst:
#         dst.write(src.read())

# with rasterio.open("data/sample.tif") as src:
gdf = gpd.read_file("data/commune.gpkg")
# gdf = gdf.to_crs(str(src.crs))
# plot the raster with the commune boundaries
fig, ax = plt.subplots()
# show(src, ax=ax)
# plot the geometry
gdf.plot(ax=ax, facecolor='none', edgecolor='red')
plt.show()
